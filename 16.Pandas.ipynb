# %%
import pandas as pd
import numpy as np

# %%
first_series = pd.Series()

# %%
first_series = pd.Series({'1':'Ahmedabad', '2':'Bangalore', '3':'Chennai','4':'Delhi','5':'Kolkatta','6':'Mumbai'})
print(first_series)
# Out:
# 1    Ahmedabad
# 2    Bangalore
# 3      Chennai
# 4        Delhi
# 5     Kolkatta
# 6       Mumbai
# dtype: object

# %%
second_series = pd.Series(np.arange(5,13,2))
print(second_series)
# Out:
# 0     5
# 1     7
# 2     9
# 3    11
# dtype: int32

# %%
third_series = pd.Series(['Mango','Apple','Banana','Orange','Grape'])
print(third_series)
# Out:
# 0     Mango
# 1     Apple
# 2    Banana
# 3    Orange
# 4     Grape
# dtype: object

# %%
print(third_series.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
first_df = pd.DataFrame({'A':[1,2,3,4], 'B':[8,7,6,5], 'C':[9,12,11,10]})
print(first_df)
# Out:
#    A  B   C
# 0  1  8   9
# 1  2  7  12
# 2  3  6  11
# 3  4  5  10

# %%
market_data = pd.read_csv('C:/Users/VKAMIRE/Documents/HD/Python/Python/Datasets/global_sales/market_fact.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-6fbf1b1a3c34> in <module>()
# ----> 1 market_data = pd.read_csv('C:/Users/VKAMIRE/Documents/HD/Python/Python/Datasets/global_sales/market_fact.csv')
#
# ~\AppData\Local\Continuum\anaconda3\envs\DhruvsdevSpace\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\envs\DhruvsdevSpace\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\envs\DhruvsdevSpace\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\DhruvsdevSpace\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~\AppData\Local\Continuum\anaconda3\envs\DhruvsdevSpace\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'C:/Users/VKAMIRE/Documents/HD/Python/Python/Datasets/global_sales/market_fact.csv' does not exist

# %%
type(market_data)
# Out:
# pandas.core.frame.DataFrame

# %%
market_data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market_data.tail(10)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8389  Ord_4444  Prod_13  SHP_6192  Cust_1519   159.4100      0.00
# 8390  Ord_5435  Prod_16  SHP_7594  Cust_1798   316.9900      0.04
# 8391  Ord_5435   Prod_4  SHP_7594  Cust_1798  1991.8985      0.07
# 8392  Ord_5384   Prod_9  SHP_7519  Cust_1798   181.5000      0.08
# 8393  Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8389              44   34.68           0.98                 0.52
# 8390              47 -276.54           8.37                 0.58
# 8391              20   88.36           7.69                 0.58
# 8392              43   -6.24           2.50                 0.37
# 8393               9   12.61           1.99                 0.44
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
market_data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
market_data.columns
# Out:
# Index([u'Ord_id', u'Prod_id', u'Ship_id', u'Cust_id', u'Sales', u'Discount',
#        u'Order_Quantity', u'Profit', u'Shipping_Cost', u'Product_Base_Margin'],
#       dtype='object')

# %%
market_data[40:55]
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 40  Ord_5035  Prod_15  SHP_7024  Cust_1710  4917.6900      0.02
# 41  Ord_5046   Prod_7  SHP_7041  Cust_1710   202.1100      0.08
# 42  Ord_1184  Prod_11  SHP_1635   Cust_452    73.4400      0.00
# 43  Ord_1189   Prod_6  SHP_1641   Cust_452    49.6100      0.00
# 44  Ord_1184   Prod_1  SHP_1634   Cust_452  1974.6600      0.06
# 45  Ord_4768  Prod_12  SHP_6650  Cust_1579     3.8500      0.08
# 46  Ord_4690   Prod_2  SHP_6545  Cust_1579   904.1200      0.07
# 47  Ord_4659   Prod_6  SHP_6493  Cust_1579  1451.5900      0.06
# 48  Ord_4622  Prod_12  SHP_6437  Cust_1579    56.2600      0.00
# 49  Ord_4657   Prod_5  SHP_6490  Cust_1579   336.8600      0.06
# 50  Ord_4682   Prod_5  SHP_6531  Cust_1579    63.9100      0.04
# 51  Ord_4768   Prod_4  SHP_6651  Cust_1579   547.0005      0.08
# 52  Ord_4755  Prod_13  SHP_6628  Cust_1579     3.4100      0.06
# 53  Ord_4659   Prod_6  SHP_6492  Cust_1579   391.9000      0.10
# 54  Ord_4682   Prod_4  SHP_6531  Cust_1579  1909.0065      0.01
#
#     Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 40              42  126.31          30.00                 0.71
# 41              40  -17.49           3.39                 0.37
# 42               3  -53.78          27.75                 0.76
# 43               1  -41.82          17.08                 0.40
# 44              32 -929.68          35.00                 0.80
# 45               1   -1.36           0.99                 0.37
# 46               4   28.81          11.79                 0.42
# 47              26  435.11          14.30                 0.37
# 48              14   28.11           0.50                 0.38
# 49              23   36.32           5.30                 0.46
# 50              14  -44.47           6.60                 0.49
# 51              10  -97.20           3.90                 0.55
# 52               1   -1.78           0.70                 0.56
# 53              11  -47.01          19.99                 0.38
# 54              32  344.13           8.99                 0.59

# %%
market_data_facts = market_data[['Discount','Order_Quantity','Profit','Shipping_Cost','Product_Base_Margin']]
market_data_facts.head()
market_data_facts.rename(columns={'Discount':'DSC'})
# Out:
#        DSC  Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0     0.01              23   -30.51           3.60                 0.56
# 1     0.01              13     4.56           0.93                 0.54
# 2     0.00              26  1148.90           2.50                 0.59
# 3     0.09              43   729.34          14.30                 0.37
# 4     0.08              35  1219.87          26.30                 0.38
# 5     0.03              23   -47.64           6.15                 0.37
# 6     0.01               5     1.32           0.50                 0.36
# 7     0.10              48  1137.91           0.99                 0.55
# 8     0.01              33    45.84           0.71                 0.52
# 9     0.07               8   -27.72           6.60                 0.37
# 10    0.01              43  1675.98           0.99                 0.56
# 11    0.05              38    79.34           4.86                 0.38
# 12    0.04              27    23.12           3.37                 0.57
# 13    0.10              15  -693.23          61.76                 0.78
# 14    0.08              10  -317.48          36.09                 0.77
# 15    0.06              48  -103.48           7.29                 0.45
# 16    0.06              30   193.12           1.39                 0.38
# 17    0.02              25  4089.27          26.00                 0.60
# 18    0.08              45  -141.26           6.81                 0.36
# 19    0.05              12   -37.03           4.20                 0.56
# 20    0.08              18   -24.03           2.31                 0.56
# 21    0.01              11   -44.54           7.86                 0.37
# 22    0.09              44   991.26          19.99                 0.43
# 23    0.05              10    -0.71           1.63                 0.36
# 24    0.08              13     3.46           7.27                 0.38
# 25    0.03              22    -2.34           0.70                 0.56
# 26    0.00              13    31.32           4.00                 0.42
# 27    0.01              28   401.80           6.66                 0.40
# 28    0.05              38  1016.97           2.50                 0.55
# 29    0.07              33  -140.54           6.89                 0.39
# ...    ...             ...      ...            ...                  ...
# 8369  0.02              41   515.62           1.49                 0.38
# 8370  0.04              20   -17.75           2.03                 0.57
# 8371  0.07              28  1049.54           8.99                 0.58
# 8372  0.03               7    12.64           1.39                 0.36
# 8373  0.10              30   -31.95           1.32                 0.83
# 8374  0.08              14  -256.93          48.20                 0.74
# 8375  0.10              47   226.53          11.63                 0.37
# 8376  0.00              36   -27.99           6.50                 0.79
# 8377  0.00              12    10.58           0.50                 0.39
# 8378  0.05              20   312.52           3.50                 0.59
# 8379  0.04              41    69.31           8.99                 0.50
# 8380  0.04              45  -143.58           7.37                 0.37
# 8381  0.01              25   561.13           8.99                 0.59
# 8382  0.00              28   -92.85           5.34                 0.38
# 8383  0.04              21  -546.98          35.00                 0.85
# 8384  0.04              10   -56.30           7.78                 0.37
# 8385  0.04              46   100.22           4.98                 0.40
# 8386  0.07              39    11.32           1.35                 0.40
# 8387  0.04               4   -16.39           6.28                 0.35
# 8388  0.03              10  -335.06          35.00                  NaN
# 8389  0.00              44    34.68           0.98                 0.52
# 8390  0.04              47  -276.54           8.37                 0.58
# 8391  0.07              20    88.36           7.69                 0.58
# 8392  0.08              43    -6.24           2.50                 0.37
# 8393  0.07               9    12.61           1.99                 0.44
# 8394  0.08              28   374.63           7.69                 0.59
# 8395  0.10              20   -74.03           6.92                 0.37
# 8396  0.02              39   -70.85           5.35                 0.40
# 8397  0.03              23   565.34          30.00                 0.62
# 8398  0.00              47   131.39           4.86                 0.38
#
# [8399 rows x 5 columns]

# %%
market_data_facts
# Out:
#       Discount  Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0         0.01              23   -30.51           3.60                 0.56
# 1         0.01              13     4.56           0.93                 0.54
# 2         0.00              26  1148.90           2.50                 0.59
# 3         0.09              43   729.34          14.30                 0.37
# 4         0.08              35  1219.87          26.30                 0.38
# 5         0.03              23   -47.64           6.15                 0.37
# 6         0.01               5     1.32           0.50                 0.36
# 7         0.10              48  1137.91           0.99                 0.55
# 8         0.01              33    45.84           0.71                 0.52
# 9         0.07               8   -27.72           6.60                 0.37
# 10        0.01              43  1675.98           0.99                 0.56
# 11        0.05              38    79.34           4.86                 0.38
# 12        0.04              27    23.12           3.37                 0.57
# 13        0.10              15  -693.23          61.76                 0.78
# 14        0.08              10  -317.48          36.09                 0.77
# 15        0.06              48  -103.48           7.29                 0.45
# 16        0.06              30   193.12           1.39                 0.38
# 17        0.02              25  4089.27          26.00                 0.60
# 18        0.08              45  -141.26           6.81                 0.36
# 19        0.05              12   -37.03           4.20                 0.56
# 20        0.08              18   -24.03           2.31                 0.56
# 21        0.01              11   -44.54           7.86                 0.37
# 22        0.09              44   991.26          19.99                 0.43
# 23        0.05              10    -0.71           1.63                 0.36
# 24        0.08              13     3.46           7.27                 0.38
# 25        0.03              22    -2.34           0.70                 0.56
# 26        0.00              13    31.32           4.00                 0.42
# 27        0.01              28   401.80           6.66                 0.40
# 28        0.05              38  1016.97           2.50                 0.55
# 29        0.07              33  -140.54           6.89                 0.39
# ...        ...             ...      ...            ...                  ...
# 8369      0.02              41   515.62           1.49                 0.38
# 8370      0.04              20   -17.75           2.03                 0.57
# 8371      0.07              28  1049.54           8.99                 0.58
# 8372      0.03               7    12.64           1.39                 0.36
# 8373      0.10              30   -31.95           1.32                 0.83
# 8374      0.08              14  -256.93          48.20                 0.74
# 8375      0.10              47   226.53          11.63                 0.37
# 8376      0.00              36   -27.99           6.50                 0.79
# 8377      0.00              12    10.58           0.50                 0.39
# 8378      0.05              20   312.52           3.50                 0.59
# 8379      0.04              41    69.31           8.99                 0.50
# 8380      0.04              45  -143.58           7.37                 0.37
# 8381      0.01              25   561.13           8.99                 0.59
# 8382      0.00              28   -92.85           5.34                 0.38
# 8383      0.04              21  -546.98          35.00                 0.85
# 8384      0.04              10   -56.30           7.78                 0.37
# 8385      0.04              46   100.22           4.98                 0.40
# 8386      0.07              39    11.32           1.35                 0.40
# 8387      0.04               4   -16.39           6.28                 0.35
# 8388      0.03              10  -335.06          35.00                  NaN
# 8389      0.00              44    34.68           0.98                 0.52
# 8390      0.04              47  -276.54           8.37                 0.58
# 8391      0.07              20    88.36           7.69                 0.58
# 8392      0.08              43    -6.24           2.50                 0.37
# 8393      0.07               9    12.61           1.99                 0.44
# 8394      0.08              28   374.63           7.69                 0.59
# 8395      0.10              20   -74.03           6.92                 0.37
# 8396      0.02              39   -70.85           5.35                 0.40
# 8397      0.03              23   565.34          30.00                 0.62
# 8398      0.00              47   131.39           4.86                 0.38
#
# [8399 rows x 5 columns]

# %%
loc_subset = market_data.loc[20:31,'Sales':'Profit']
loc_subset
# Out:
#         Sales  Discount  Order_Quantity   Profit
# 20    57.1700      0.08              18   -24.03
# 21    81.2500      0.01              11   -44.54
# 22  3202.2500      0.09              44   991.26
# 23    35.6400      0.05              10    -0.71
# 24   197.6100      0.08              13     3.46
# 25    38.2600      0.03              22    -2.34
# 26   109.5800      0.00              13    31.32
# 27  1062.6900      0.01              28   401.80
# 28  3594.7435      0.05              38  1016.97
# 29   139.9800      0.07              33  -140.54
# 30   129.1000      0.00              27   -59.82
# 31    68.9200      0.04              22     2.63

# %%
loc_subset.sort_index(axis=1, ascending=False,inplace = True)
print(loc_subset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91ef387f38d4> in <module>()
# ----> 1 loc_subset.sort_index(axis=1, ascending=False,inplace = True)
#       2 print(loc_subset)
#
# NameError: name 'loc_subset' is not defined

# %%
help(loc_subset.sort_index)

# %%
loc_subset.sort_values(by='Sales',ascending =False,inplace=True)
print(loc_subset)
# Out:
#         Sales  Discount  Order_Quantity   Profit
# 28  3594.7435      0.05              38  1016.97
# 22  3202.2500      0.09              44   991.26
# 27  1062.6900      0.01              28   401.80
# 24   197.6100      0.08              13     3.46
# 29   139.9800      0.07              33  -140.54
# 30   129.1000      0.00              27   -59.82
# 26   109.5800      0.00              13    31.32
# 21    81.2500      0.01              11   -44.54
# 31    68.9200      0.04              22     2.63
# 20    57.1700      0.08              18   -24.03
# 25    38.2600      0.03              22    -2.34
# 23    35.6400      0.05              10    -0.71

# %%
loc_subset.sort_values(by=['Profit','Sales'],ascending =False,inplace=True)
print(loc_subset)

# %%
prod_data = pd.read_csv('C:/Users/VKAMIRE/Documents/HD/Python/Python/Datasets/global_sales/prod_dimen.csv')
prod_data.dtypes
# Out:
# Product_Category        object
# Product_Sub_Category    object
# Prod_id                 object
# dtype: object

# %%
prod_data['Product_Category'] = prod_data['Product_Category'].astype('category')
print(prod_data.dtypes)
# Out:
# Product_Category        category
# Product_Sub_Category      object
# Prod_id                   object
# dtype: object

# %%
combined_data = pd.merge(market_data, prod_data, on='Prod_id', how='outer')
combined_data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 5     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 6     Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 7     Ord_4506  Prod_16  SHP_6273  Cust_1544     92.02      0.07
# 8     Ord_4080  Prod_16  SHP_5688  Cust_1388    666.40      0.00
# 9     Ord_1551  Prod_16  SHP_2145   Cust_531    184.77      0.00
# 10    Ord_1579  Prod_16  SHP_2178   Cust_566    139.37      0.04
# 11    Ord_1429  Prod_16  SHP_1976   Cust_510    539.06      0.05
# 12    Ord_2471  Prod_16  SHP_3386   Cust_965     90.93      0.05
# 13    Ord_2873  Prod_16  SHP_3957  Cust_1052    138.55      0.03
# 14      Ord_43  Prod_16    SHP_56    Cust_34   9620.82      0.04
# 15     Ord_956  Prod_16  SHP_1324   Cust_346    503.17      0.01
# 16     Ord_975  Prod_16  SHP_1345   Cust_346    638.91      0.02
# 17    Ord_2385  Prod_16  SHP_3273   Cust_939    138.84      0.00
# 18    Ord_4307  Prod_16  SHP_6011  Cust_1440    395.37      0.07
# 19    Ord_4328  Prod_16  SHP_6033  Cust_1440    103.03      0.07
# 20    Ord_4031  Prod_16  SHP_5613  Cust_1391    171.50      0.02
# 21     Ord_208  Prod_16   SHP_284    Cust_67    327.15      0.04
# 22    Ord_1154  Prod_16  SHP_1590   Cust_444    483.64      0.10
# 23    Ord_1486  Prod_16  SHP_2052   Cust_513    487.50      0.05
# 8385       TECHNOLOGY                COPIERS AND FAX
# 8386       TECHNOLOGY                COPIERS AND FAX
# 8387       TECHNOLOGY                COPIERS AND FAX
# 8388       TECHNOLOGY                COPIERS AND FAX
# 8389       TECHNOLOGY                COPIERS AND FAX
# 8390       TECHNOLOGY                COPIERS AND FAX
# 8391       TECHNOLOGY                COPIERS AND FAX
# 8392       TECHNOLOGY                COPIERS AND FAX
# 8393       TECHNOLOGY                COPIERS AND FAX
# 8394       TECHNOLOGY                COPIERS AND FAX
# 8395       TECHNOLOGY                COPIERS AND FAX
# 8396       TECHNOLOGY                COPIERS AND FAX
# 8397       TECHNOLOGY                COPIERS AND FAX
# 8398       TECHNOLOGY                COPIERS AND FAX
#
# [8399 rows x 12 columns]

# %%
cust_data = pd.read_csv('C:/Users/VKAMIRE/Documents/HD/Python/Python/Datasets/global_sales/cust_dimen.csv')
ship_data = pd.read_csv('C:/Users/VKAMIRE/Documents/HD/Python/Python/Datasets/global_sales/shipping_dimen.csv')

combined_data2 = pd.merge(combined_data, cust_data, on = 'Cust_id',how='outer')
combined_master = pd.merge(combined_data2, ship_data, on = 'Ship_id', how='outer')
combined_master

# %%
# Horizontal Subset
#get number of observations with a profit greater than 1000
profit_grt_1000 = combined_master[combined_master.Profit > 1000]
profit_grt_1000_counts = len(profit_grt_1000)
print(profit_grt_1000_counts)
profit_grt_1000

# %%
high_value = combined_master.query('Sales >1000 and Order_Quantity <30')
high_value

# %%
help(combined_master.where)

# %%
#Using where

high_value_where = combined_master.where(combined_master.Sales >1000,-combined_master)
high_value_where

# %%
print(len(high_value_where))
print(len(high_value_where.dropna(axis=0)))

# %%
print(combined_master.Product_Category.dtype)
combined_master['Product_Category'] = combined_master['Product_Category'].astype('category')

print(combined_master.Product_Category.dtype)

# %%
combined_master

# %%
combined_master.groupby(['Product_Category'])['Sales'].mean()

# %%
combined_master.groupby(['Product_Category','Product_Sub_Category'])[['Sales','Profit']].mean()

# %%
combined_master.groupby(['Product_Category','Product_Sub_Category'])[['Sales','Profit']].count()

# %%
combined_master.groupby(['Product_Category','Product_Sub_Category'])[['Sales','Profit']].sum()

# %%
groupings = combined_master.groupby(['Product_Category','Region'])

# %%
groupings.agg([np.sum, np.mean, np.std])

# %%
groupings.agg([np.sum, np.mean, np.std])['Order_Quantity']

# %%
pivot_ex = combined_master.drop_duplicates(subset = 'Ship_Date', inplace = False)

# %%
def get_id(any_id):
    out = any_id.split('_')[1]
    return out

# %%
get_id_lambda = lambda x : x.split('_')[1]

# %%
combined_master['Cust_id_new'] = combined_master['Cust_id'].apply(get_id)
combined_master['Ord_id_new'] = combined_master['Ord_id'].apply(get_id_lambda)

combined_master.head()

# %%
combined_master.to_csv('combined.csv')

# %%
year=[1,1000,1500,1650,1750,1804,1850,1900,1927,1950,1955,1960,1965,1970,1975,1980,1985,1990,1995,1999,2006,2009,2011,2025,2043,2083
]

# %%
pop=[0.2,0.275,0.45,0.5,0.7,1,1.2,1.6,2,2.55,2.8,3,3.3,3.7,4,4.5,4.85,5.3,5.7,6,6.5,6.8,7,8,9,10]

# %%
import matplotlib.pyplot as plt
#help(plt.plot)

# %%
plt.plot(year,pop)
plt.show()

# %%
plt.scatter(year,pop)
plt.show()

# %%
life_exp=[43.828000000000003,
 76.423000000000002,
 72.301000000000002,
 42.731000000000002,
 75.319999999999993,
 81.234999999999999,
 79.828999999999994,
 75.635000000000005,
 64.061999999999998,
 79.441000000000003,
 56.728000000000002,
 65.554000000000002,
 74.852000000000004,
 50.728000000000002,
 72.390000000000001,
 73.004999999999995,
 52.295000000000002,
 49.579999999999998,
 59.722999999999999,
 50.43,
 80.653000000000006,
 44.741000000000007,
 50.651000000000003,
 78.552999999999997,
 72.960999999999999,
 72.888999999999996,
 65.152000000000001,
 46.462000000000003,
 55.322000000000003,
 78.781999999999996,
 48.328000000000003,
 75.748000000000005,
 78.272999999999996,
 76.486000000000004,
 78.331999999999994,
 54.790999999999997,
 72.234999999999999,
 74.994,
 71.338000000000022,
 71.878,
 51.578999999999994,
 58.039999999999999,
 52.947000000000003,
 79.313000000000002,
 80.656999999999996,
 56.734999999999999,
 59.448,
 79.406000000000006,
 60.021999999999998,
 79.483000000000004,
 70.259,
 56.006999999999998,
 46.388000000000012,
 60.915999999999997,
 70.198000000000008,
 82.207999999999998,
 73.338000000000022,
 81.757000000000005,
 64.698000000000008,
 70.650000000000006,
 70.963999999999999,
 59.545000000000002,
 78.885000000000005,
 80.745000000000005,
 80.546000000000006,
 72.566999999999993,
 82.602999999999994,
 72.534999999999997,
 54.109999999999999,
 67.296999999999997,
 78.623000000000005,
 77.588000000000022,
 71.992999999999995,
 42.591999999999999,
 45.677999999999997,
 73.951999999999998,
 59.443000000000012,
 48.302999999999997,
 74.241,
 54.466999999999999,
 64.164000000000001,
 72.801000000000002,
 76.194999999999993,
 66.802999999999997,
 74.543000000000006,
 71.164000000000001,
 42.082000000000001,
 62.069000000000003,
 52.906000000000013,
 63.784999999999997,
 79.762,
 80.203999999999994,
 72.899000000000001,
 56.866999999999997,
 46.859000000000002,
 80.195999999999998,
 75.640000000000001,
 65.483000000000004,
 75.536999999999978,
 71.751999999999995,
 71.421000000000006,
 71.688000000000002,
 75.563000000000002,
 78.097999999999999,
 78.746000000000024,
 76.441999999999993,
 72.475999999999999,
 46.241999999999997,
 65.528000000000006,
 72.777000000000001,
 63.061999999999998,
 74.001999999999995,
 42.568000000000012,
 79.971999999999994,
 74.662999999999997,
 77.926000000000002,
 48.158999999999999,
 49.338999999999999,
 80.941000000000003,
 72.396000000000001,
 58.555999999999997,
 39.613,
 80.884,
 81.701000000000022,
 74.143000000000001,
 78.400000000000006,
 52.517000000000003,
 70.616,
 58.420000000000002,
 69.819000000000003,
 73.923000000000002,
 71.777000000000001,
 51.542000000000002,
 79.424999999999997,
 78.242000000000004,
 76.384,
 73.747,
 74.248999999999995,
 73.421999999999997,
 62.698,
 42.383999999999993,
 43.487000000000002]

# %%
